# %%
import os
os.environ["DJANGO_SETTINGS_MODULE"] = "mydjango13.settings"
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

# %%
from mall.models import Shop

# %%
Shop.objects.all()
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" DESC LIMIT 21; args=()
# <QuerySet [<Shop: Shop object (2)>, <Shop: Shop object (1)>]>

# %%
Shop
# Out:
# mall.models.Shop

# %% [markdown]
# # Create

# %%
shop = Shop() #FirstShop(0), first_shop(x), firstShop(x), first_Shop(x)
shop.name = "투썸플레이스"
shop.telephone = "042-123-1234"

# %%
shop.save()
# Out:
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('투썸플레이스', '', '042-123-1234', '', '2021-12-01 06:40:55.474802', '2021-12-01 06:40:55.474802'); args=['투썸플레이스', '', '042-123-1234', '', '2021-12-01 06:40:55.474802', '2021-12-01 06:40:55.474802']

# %%
shop = Shop.objects.create(
    name = "셀프24시빨래방",
    telephone = "042-1234-4321",
)
shop
# Out:
# (0.032) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('셀프24시빨래방', '', '042-1234-4321', '', '2021-12-01 06:40:55.514684', '2021-12-01 06:40:55.514684'); args=['셀프24시빨래방', '', '042-1234-4321', '', '2021-12-01 06:40:55.514684', '2021-12-01 06:40:55.514684']
# <Shop: Shop object (4)>

# %% [markdown]
# # Select

# %%
qs = Shop.objects.all()

# %%
for shop in qs:
    print(shop.pk, shop.name, shop.telephone)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" DESC; args=()
# 4 셀프24시빨래방 042-1234-4321
# 3 투썸플레이스 042-123-1234
# 2 셀프24시빨래방 042-1234-4321
# 1 투썸플레이스 042-123-1234

# %%
qs.order_by("-id") # , "created_at" 정렬은 가급적 단일 컬럼을 쓰세요
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" DESC LIMIT 21; args=()
# <QuerySet [<Shop: Shop object (4)>, <Shop: Shop object (3)>, <Shop: Shop object (2)>, <Shop: Shop object (1)>]>

# %% [markdown]
# ## 데이터 뻥튀기

# %%
for i in range(1,101):
    name = f"가게명#{i}"
    telephone = f"042-1234-9{i:03}"
    Shop.objects.create(
        name=name,
        telephone=telephone,
    )
# Out:
# (0.031) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#1', '', '042-1234-9001', '', '2021-12-01 06:45:24.578048', '2021-12-01 06:45:24.578048'); args=['가게명#1', '', '042-1234-9001', '', '2021-12-01 06:45:24.578048', '2021-12-01 06:45:24.578048']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#2', '', '042-1234-9002', '', '2021-12-01 06:45:24.604977', '2021-12-01 06:45:24.604977'); args=['가게명#2', '', '042-1234-9002', '', '2021-12-01 06:45:24.604977', '2021-12-01 06:45:24.604977']
# (0.031) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#3', '', '042-1234-9003', '', '2021-12-01 06:45:24.623973', '2021-12-01 06:45:24.623973'); args=['가게명#3', '', '042-1234-9003', '', '2021-12-01 06:45:24.623973', '2021-12-01 06:45:24.623973']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#4', '', '042-1234-9004', '', '2021-12-01 06:45:24.645025', '2021-12-01 06:45:24.645025'); args=['가게명#4', '', '042-1234-9004', '', '2021-12-01 06:45:24.645025', '2021-12-01 06:45:24.645025']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#5', '', '042-1234-9005', '', '2021-12-01 06:45:24.659441', '2021-12-01 06:45:24.659441'); args=['가게명#5', '', '042-1234-9005', '', '2021-12-01 06:45:24.659441', '2021-12-01 06:45:24.659441']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#6', '', '042-1234-9006', '', '2021-12-01 06:45:24.676408', '2021-12-01 06:45:24.676408'); args=['가게명#6', '', '042-1234-9006', '', '2021-12-01 06:45:24.676408', '2021-12-01 06:45:24.676408']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#7', '', '042-1234-9007', '', '2021-12-01 06:45:24.696007', '2021-12-01 06:45:24.696007'); args=['가게명#7', '', '042-1234-9007', '', '2021-12-01 06:45:24.696007', '2021-12-01 06:45:24.696007']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#8', '', '042-1234-9008', '', '2021-12-01 06:45:24.710892', '2021-12-01 06:45:24.710892'); args=['가게명#8', '', '042-1234-9008', '', '2021-12-01 06:45:24.710892', '2021-12-01 06:45:24.710892']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#9', '', '042-1234-9009', '', '2021-12-01 06:45:24.729986', '2021-12-01 06:45:24.729986'); args=['가게명#9', '', '042-1234-9009', '', '2021-12-01 06:45:24.729986', '2021-12-01 06:45:24.729986']
# (0.031) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#10', '', '042-1234-9010', '', '2021-12-01 06:45:24.749276', '2021-12-01 06:45:24.749276'); args=['가게명#10', '', '042-1234-9010', '', '2021-12-01 06:45:24.749276', '2021-12-01 06:45:24.749276']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#11', '', '042-1234-9011', '', '2021-12-01 06:45:24.771107', '2021-12-01 06:45:24.771107'); args=['가게명#11', '', '042-1234-9011', '', '2021-12-01 06:45:24.771107', '2021-12-01 06:45:24.771107']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#12', '', '042-1234-9012', '', '2021-12-01 06:45:24.789100', '2021-12-01 06:45:24.789100'); args=['가게명#12', '', '042-1234-9012', '', '2021-12-01 06:45:24.789100', '2021-12-01 06:45:24.789100']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#13', '', '042-1234-9013', '', '2021-12-01 06:45:24.808076', '2021-12-01 06:45:24.808076'); args=['가게명#13', '', '042-1234-9013', '', '2021-12-01 06:45:24.808076', '2021-12-01 06:45:24.808076']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#14', '', '042-1234-9014', '', '2021-12-01 06:45:24.827837', '2021-12-01 06:45:24.827837'); args=['가게명#14', '', '042-1234-9014', '', '2021-12-01 06:45:24.827837', '2021-12-01 06:45:24.827837']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#15', '', '042-1234-9015', '', '2021-12-01 06:45:24.845959', '2021-12-01 06:45:24.845959'); args=['가게명#15', '', '042-1234-9015', '', '2021-12-01 06:45:24.845959', '2021-12-01 06:45:24.845959']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#16', '', '042-1234-9016', '', '2021-12-01 06:45:24.863599', '2021-12-01 06:45:24.863599'); args=['가게명#16', '', '042-1234-9016', '', '2021-12-01 06:45:24.863599', '2021-12-01 06:45:24.863599']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#17', '', '042-1234-9017', '', '2021-12-01 06:45:24.881620', '2021-12-01 06:45:24.881620'); args=['가게명#17', '', '042-1234-9017', '', '2021-12-01 06:45:24.881620', '2021-12-01 06:45:24.881620']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#18', '', '042-1234-9018', '', '2021-12-01 06:45:24.896051', '2021-12-01 06:45:24.896051'); args=['가게명#18', '', '042-1234-9018', '', '2021-12-01 06:45:24.896051', '2021-12-01 06:45:24.896051']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#19', '', '042-1234-9019', '', '2021-12-01 06:45:24.911950', '2021-12-01 06:45:24.911950'); args=['가게명#19', '', '042-1234-9019', '', '2021-12-01 06:45:24.911950', '2021-12-01 06:45:24.911950']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#20', '', '042-1234-9020', '', '2021-12-01 06:45

# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#86', '', '042-1234-9086', '', '2021-12-01 06:45:26.053388', '2021-12-01 06:45:26.053388'); args=['가게명#86', '', '042-1234-9086', '', '2021-12-01 06:45:26.053388', '2021-12-01 06:45:26.053388']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#87', '', '042-1234-9087', '', '2021-12-01 06:45:26.068189', '2021-12-01 06:45:26.068189'); args=['가게명#87', '', '042-1234-9087', '', '2021-12-01 06:45:26.068189', '2021-12-01 06:45:26.068189']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#88', '', '042-1234-9088', '', '2021-12-01 06:45:26.083745', '2021-12-01 06:45:26.083745'); args=['가게명#88', '', '042-1234-9088', '', '2021-12-01 06:45:26.083745', '2021-12-01 06:45:26.083745']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#89', '', '042-1234-9089', '', '2021-12-01 06:45:26.098122', '2021-12-01 06:45:26.098122'); args=['가게명#89', '', '042-1234-9089', '', '2021-12-01 06:45:26.098122', '2021-12-01 06:45:26.098122']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#90', '', '042-1234-9090', '', '2021-12-01 06:45:26.115123', '2021-12-01 06:45:26.115123'); args=['가게명#90', '', '042-1234-9090', '', '2021-12-01 06:45:26.115123', '2021-12-01 06:45:26.115123']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#91', '', '042-1234-9091', '', '2021-12-01 06:45:26.128122', '2021-12-01 06:45:26.128122'); args=['가게명#91', '', '042-1234-9091', '', '2021-12-01 06:45:26.128122', '2021-12-01 06:45:26.128122']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#92', '', '042-1234-9092', '', '2021-12-01 06:45:26.147673', '2021-12-01 06:45:26.147673'); args=['가게명#92', '', '042-1234-9092', '', '2021-12-01 06:45:26.147673', '2021-12-01 06:45:26.147673']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#93', '', '042-1234-9093', '', '2021-12-01 06:45:26.162453', '2021-12-01 06:45:26.162453'); args=['가게명#93', '', '042-1234-9093', '', '2021-12-01 06:45:26.162453', '2021-12-01 06:45:26.162453']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#94', '', '042-1234-9094', '', '2021-12-01 06:45:26.175017', '2021-12-01 06:45:26.175017'); args=['가게명#94', '', '042-1234-9094', '', '2021-12-01 06:45:26.175017', '2021-12-01 06:45:26.175017']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#95', '', '042-1234-9095', '', '2021-12-01 06:45:26.191103', '2021-12-01 06:45:26.191103'); args=['가게명#95', '', '042-1234-9095', '', '2021-12-01 06:45:26.191103', '2021-12-01 06:45:26.191103']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#96', '', '042-1234-9096', '', '2021-12-01 06:45:26.206938', '2021-12-01 06:45:26.206938'); args=['가게명#96', '', '042-1234-9096', '', '2021-12-01 06:45:26.206938', '2021-12-01 06:45:26.206938']
# (0.000) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#97', '', '042-1234-9097', '', '2021-12-01 06:45:26.221125', '2021-12-01 06:45:26.221125'); args=['가게명#97', '', '042-1234-9097', '', '2021-12-01 06:45:26.221125', '2021-12-01 06:45:26.221125']
# (0.015) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#98', '', '042-1234-9098', '', '2021-12-01 06:45:26.236083', '2021-12-01 06:45:26.236083'); args=['가게명#98', '', '042-1234-9098', '', '2021-12-01 06:45:26.236083', '2021-12-01 06:45:26.236083']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#99', '', '042-1234-9099', '', '2021-12-01 06:45:26.254037', '2021-12-01 06:45:26.254037'); args=['가게명#99', '', '042-1234-9099', '', '2021-12-01 06:45:26.254037', '2021-12-01 06:45:26.254037']
# (0.016) INSERT INTO "mall_shop" ("name", "description", "telephone", "photo", "created_at", "updated_at") VALUES ('가게명#100', '', '042-1234-9100', '', '2021-12-01 06:45:26.269993', '2021-12-01 06:45:26.269993'); args=['가게명#100', '', '042-1234-9100', '', '2021-12-01 06:45:26.269993', '2021-12-01 06:45:26.269993']

# %% [markdown]
# ## Slicing

# %%
qs = Shop.objects.all()

# %%
qs[:10] #first 10 rows
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" DESC LIMIT 10; args=()
# <QuerySet [<Shop: Shop object (104)>, <Shop: Shop object (103)>, <Shop: Shop object (102)>, <Shop: Shop object (101)>, <Shop: Shop object (100)>, <Shop: Shop object (99)>, <Shop: Shop object (98)>, <Shop: Shop object (97)>, <Shop: Shop object (96)>, <Shop: Shop object (95)>]>

# %%
qs[0:10:2] #시작 엔드 범위를 전부 가져와서 반환을 건너뛰어서 반환
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" DESC LIMIT 10; args=()
# [<Shop: Shop object (104)>,
#  <Shop: Shop object (102)>,
#  <Shop: Shop object (100)>,
#  <Shop: Shop object (98)>,
#  <Shop: Shop object (96)>]

# %%
qs[-10:] # last 10 rows => Not supported in DB
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9932/1220812754.py in <module>
# ----> 1 qs[-10:]
#
# C:\Python310\lib\site-packages\django\db\models\query.py in __getitem__(self, k)
#     292                 % type(k).__name__
#     293             )
# --> 294         assert ((not isinstance(k, slice) and (k >= 0)) or
#     295                 (isinstance(k, slice) and (k.start is None or k.start >= 0) and
#     296                  (k.stop is None or k.stop >= 0))), \
#
# AssertionError: Negative indexing is not supported.

# %%
for shop in reversed(qs.order_by("id")[:10]):
    print(shop.pk, shop.name, shop.telephone)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" ASC LIMIT 10; args=()
# 10 가게명#6 042-1234-9006
# 9 가게명#5 042-1234-9005
# 8 가게명#4 042-1234-9004
# 7 가게명#3 042-1234-9003
# 6 가게명#2 042-1234-9002
# 5 가게명#1 042-1234-9001
# 4 셀프24시빨래방 042-1234-4321
# 3 투썸플레이스 042-123-1234
# 2 셀프24시빨래방 042-1234-4321
# 1 투썸플레이스 042-123-1234

# %% [markdown]
# ## Conditions

# %%
qs = Shop.objects.all()

# %%
# filter <-> exclude

qs.filter(pk=1)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 1 ORDER BY "mall_shop"."id" DESC LIMIT 21; args=(1,)
# <QuerySet [<Shop: Shop object (1)>]>

# %%
qs.exclude(pk=1)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE NOT ("mall_shop"."id" = 1) ORDER BY "mall_shop"."id" DESC LIMIT 21; args=(1,)
# <QuerySet [<Shop: Shop object (104)>, <Shop: Shop object (103)>, <Shop: Shop object (102)>, <Shop: Shop object (101)>, <Shop: Shop object (100)>, <Shop: Shop object (99)>, <Shop: Shop object (98)>, <Shop: Shop object (97)>, <Shop: Shop object (96)>, <Shop: Shop object (95)>, <Shop: Shop object (94)>, <Shop: Shop object (93)>, <Shop: Shop object (92)>, <Shop: Shop object (91)>, <Shop: Shop object (90)>, <Shop: Shop object (89)>, <Shop: Shop object (88)>, <Shop: Shop object (87)>, <Shop: Shop object (86)>, <Shop: Shop object (85)>, '...(remaining elements truncated)...']>

# %%
# lt = less than             <
# lte = less than equal      <=
# gt = greater than          >
# gte = greater than equal   >=

qs.filter(
    pk__gte=5,
    pk__lt=10, # less than
)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE ("mall_shop"."id" >= 5 AND "mall_shop"."id" < 10) ORDER BY "mall_shop"."id" DESC LIMIT 21; args=(5, 10)
# <QuerySet [<Shop: Shop object (9)>, <Shop: Shop object (8)>, <Shop: Shop object (7)>, <Shop: Shop object (6)>, <Shop: Shop object (5)>]>

# %%
qs.filter(pk__gte=5).filter(pk__lt=10)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE ("mall_shop"."id" >= 5 AND "mall_shop"."id" < 10) ORDER BY "mall_shop"."id" DESC LIMIT 21; args=(5, 10)
# <QuerySet [<Shop: Shop object (9)>, <Shop: Shop object (8)>, <Shop: Shop object (7)>, <Shop: Shop object (6)>, <Shop: Shop object (5)>]>

# %%
qs1 = Shop.objects.all()
qs1 = qs.filter(pk__gte=5)
qs1 = qs.filter(pk__lt=10)

# %%
qs2 = Shop.objects.all().filter(pk__gte=5).filter(pk__lt=10)

# %%
# Query is Lazy.

# %%
qs = Shop.objects.all()

# %%
Shop.objects.all()
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" DESC LIMIT 21; args=()
# <QuerySet [<Shop: Shop object (104)>, <Shop: Shop object (103)>, <Shop: Shop object (102)>, <Shop: Shop object (101)>, <Shop: Shop object (100)>, <Shop: Shop object (99)>, <Shop: Shop object (98)>, <Shop: Shop object (97)>, <Shop: Shop object (96)>, <Shop: Shop object (95)>, <Shop: Shop object (94)>, <Shop: Shop object (93)>, <Shop: Shop object (92)>, <Shop: Shop object (91)>, <Shop: Shop object (90)>, <Shop: Shop object (89)>, <Shop: Shop object (88)>, <Shop: Shop object (87)>, <Shop: Shop object (86)>, <Shop: Shop object (85)>, '...(remaining elements truncated)...']>

# %%
qs = Shop.objects.all()
shop_list = list(qs)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" ORDER BY "mall_shop"."id" DESC; args=()

# %% [markdown]
# ## Get 1 Row

# %%
pk = 10
not_existed_pk = 100000

# %%
shop = Shop.objects.get(pk=pk) # 가져올 대상이 1개임을 기대, 한계가 아니면 예회가 발생
shop
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 10 LIMIT 21; args=(10,)
# <Shop: Shop object (10)>

# %%
Shop.objects.get(pk=not_existed_pk) # Shop.DoesNotExist 예외가 발생
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 100000 LIMIT 21; args=(100000,)
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9932/3709706867.py in <module>
# ----> 1 Shop.objects.get(pk=not_existed_pk) # Shop.DoesNotExist 예외가 발생
#
# C:\Python310\lib\site-packages\django\db\models\manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# C:\Python310\lib\site-packages\django\db\models\query.py in get(self, *args, **kwargs)
#     433             return clone._result_cache[0]
#     434         if not num:
# --> 435             raise self.model.DoesNotExist(
#     436                 "%s matching query does not exist." %
#     437                 self.model._meta.object_name
#
# DoesNotExist: Shop matching query does not exist.

# %%
shop = Shop.objects.filter(pk = pk)[0]
shop
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 10 ORDER BY "mall_shop"."id" DESC LIMIT 1; args=(10,)
# <Shop: Shop object (10)>

# %%
Shop.objects.filter(pk=not_existed_pk)[0] #indexError 예외가 발생
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 100000 ORDER BY "mall_shop"."id" DESC LIMIT 1; args=(100000,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9932/1689393790.py in <module>
# ----> 1 Shop.objects.filter(pk=not_existed_pk)[0]
#
# C:\Python310\lib\site-packages\django\db\models\query.py in __getitem__(self, k)
#     316         qs.query.set_limits(k, k + 1)
#     317         qs._fetch_all()
# --> 318         return qs._result_cache[0]
#     319
#     320     def __class_getitem__(cls, *args, **kwargs):
#
# IndexError: list index out of range

# %%
Shop.objects.filter(pk=not_existed_pk).first() # 지정 Row가 없다면 None을 반환할 뿐, 예외는 발생x
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 100000 ORDER BY "mall_shop"."id" DESC LIMIT 1; args=(100000,)

# %% [markdown]
# ## Conditions(OR)

# %%
qs = Shop.objects.all()
qs.filter(pk__gte=5, pk__lt=10)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE ("mall_shop"."id" >= 5 AND "mall_shop"."id" < 10) ORDER BY "mall_shop"."id" DESC LIMIT 21; args=(5, 10)
# <QuerySet [<Shop: Shop object (9)>, <Shop: Shop object (8)>, <Shop: Shop object (7)>, <Shop: Shop object (6)>, <Shop: Shop object (5)>]>

# %%
from django.db.models import Q

# %%
Q(pk__gte=5)
# Out:
# <Q: (AND: ('pk__gte', 5))>

# %%
Q(pk__lt=10)
# Out:
# <Q: (AND: ('pk__lt', 10))>

# %%
Q(pk__gte=5) & Q(pk__lt=10)
# Out:
# <Q: (AND: ('pk__gte', 5), ('pk__lt', 10))>

# %%
Q(pk__gte=5) | Q(pk__lt=10)
# Out:
# <Q: (OR: ('pk__gte', 5), ('pk__lt', 10))>

# %%
qs = Shop.objects.all()
qs.filter(
    Q(pk__gte=5) | Q(pk__lt=10)
)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE ("mall_shop"."id" >= 5 OR "mall_shop"."id" < 10) ORDER BY "mall_shop"."id" DESC LIMIT 21; args=(5, 10)
# <QuerySet [<Shop: Shop object (104)>, <Shop: Shop object (103)>, <Shop: Shop object (102)>, <Shop: Shop object (101)>, <Shop: Shop object (100)>, <Shop: Shop object (99)>, <Shop: Shop object (98)>, <Shop: Shop object (97)>, <Shop: Shop object (96)>, <Shop: Shop object (95)>, <Shop: Shop object (94)>, <Shop: Shop object (93)>, <Shop: Shop object (92)>, <Shop: Shop object (91)>, <Shop: Shop object (90)>, <Shop: Shop object (89)>, <Shop: Shop object (88)>, <Shop: Shop object (87)>, <Shop: Shop object (86)>, <Shop: Shop object (85)>, '...(remaining elements truncated)...']>

# %%
conditions = Q(pk__gte=5)
# conditions = conditions | Q(pk__lt=10)
conditions != Q(pk__lt=10)

conditions
# Out:
# <Q: (AND: ('pk__gte', 5))>

# %% [markdown]
# # Update Rows

# %% [markdown]
# ## 지정 Row

# %%
qs=Shop.objects.all()
shop=qs.get(pk=10)
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" = 10 LIMIT 21; args=(10,)

# %%
shop.name, shop.telephone
# Out:
# ('가게명#6', '042-1234-9006')

# %%
shop.telephone = "042-1234-0006"

# %%
shop.save()
# Out:
# (0.032) UPDATE "mall_shop" SET "name" = '가게명#6', "description" = '', "telephone" = '042-1234-0006', "photo" = '', "created_at" = '2021-12-01 06:45:24.676408', "updated_at" = '2021-12-01 07:38:51.433291' WHERE "mall_shop"."id" = 10; args=('가게명#6', '', '042-1234-0006', '', '2021-12-01 06:45:24.676408', '2021-12-01 07:38:51.433291', 10)

# %% [markdown]
# ## 지정 범위의 Rows

# %%
qs = Shop.objects.all()
qs = qs.filter(pk__lte=10)
qs.update(
    description="not used description"
)
# Out:
# (0.031) UPDATE "mall_shop" SET "description" = 'not used description' WHERE "mall_shop"."id" <= 10; args=('not used description', 10)
# 10

# %%
qs = Shop.objects.all()
qs = qs.filter(pk__lte=10)
for shop in qs:
    shop.description = "not used description"
    shop.save()
# Out:
# (0.000) SELECT "mall_shop"."id", "mall_shop"."name", "mall_shop"."description", "mall_shop"."telephone", "mall_shop"."photo", "mall_shop"."created_at", "mall_shop"."updated_at" FROM "mall_shop" WHERE "mall_shop"."id" <= 10 ORDER BY "mall_shop"."id" DESC; args=(10,)
# (0.016) UPDATE "mall_shop" SET "name" = '가게명#6', "description" = 'not used description', "telephone" = '042-1234-0006', "photo" = '', "created_at" = '2021-12-01 06:45:24.676408', "updated_at" = '2021-12-01 07:42:02.148216' WHERE "mall_shop"."id" = 10; args=('가게명#6', 'not used description', '042-1234-0006', '', '2021-12-01 06:45:24.676408', '2021-12-01 07:42:02.148216', 10)
# (0.015) UPDATE "mall_shop" SET "name" = '가게명#5', "description" = 'not used description', "telephone" = '042-1234-9005', "photo" = '', "created_at" = '2021-12-01 06:45:24.659441', "updated_at" = '2021-12-01 07:42:02.170174' WHERE "mall_shop"."id" = 9; args=('가게명#5', 'not used description', '042-1234-9005', '', '2021-12-01 06:45:24.659441', '2021-12-01 07:42:02.170174', 9)
# (0.016) UPDATE "mall_shop" SET "name" = '가게명#4', "description" = 'not used description', "telephone" = '042-1234-9004', "photo" = '', "created_at" = '2021-12-01 06:45:24.645025', "updated_at" = '2021-12-01 07:42:02.187112' WHERE "mall_shop"."id" = 8; args=('가게명#4', 'not used description', '042-1234-9004', '', '2021-12-01 06:45:24.645025', '2021-12-01 07:42:02.187112', 8)
# (0.016) UPDATE "mall_shop" SET "name" = '가게명#3', "description" = 'not used description', "telephone" = '042-1234-9003', "photo" = '', "created_at" = '2021-12-01 06:45:24.623973', "updated_at" = '2021-12-01 07:42:02.203068' WHERE "mall_shop"."id" = 7; args=('가게명#3', 'not used description', '042-1234-9003', '', '2021-12-01 06:45:24.623973', '2021-12-01 07:42:02.203068', 7)
# (0.015) UPDATE "mall_shop" SET "name" = '가게명#2', "description" = 'not used description', "telephone" = '042-1234-9002', "photo" = '', "created_at" = '2021-12-01 06:45:24.604977', "updated_at" = '2021-12-01 07:42:02.219024' WHERE "mall_shop"."id" = 6; args=('가게명#2', 'not used description', '042-1234-9002', '', '2021-12-01 06:45:24.604977', '2021-12-01 07:42:02.219024', 6)
# (0.015) UPDATE "mall_shop" SET "name" = '가게명#1', "description" = 'not used description', "telephone" = '042-1234-9001', "photo" = '', "created_at" = '2021-12-01 06:45:24.578048', "updated_at" = '2021-12-01 07:42:02.235979' WHERE "mall_shop"."id" = 5; args=('가게명#1', 'not used description', '042-1234-9001', '', '2021-12-01 06:45:24.578048', '2021-12-01 07:42:02.235979', 5)
# (0.016) UPDATE "mall_shop" SET "name" = '셀프24시빨래방', "description" = 'not used description', "telephone" = '042-1234-4321', "photo" = '', "created_at" = '2021-12-01 06:40:55.514684', "updated_at" = '2021-12-01 07:42:02.253979' WHERE "mall_shop"."id" = 4; args=('셀프24시빨래방', 'not used description', '042-1234-4321', '', '2021-12-01 06:40:55.514684', '2021-12-01 07:42:02.253979', 4)
# (0.016) UPDATE "mall_shop" SET "name" = '투썸플레이스', "description" = 'not used description', "telephone" = '042-123-1234', "photo" = '', "created_at" = '2021-12-01 06:40:55.474802', "updated_at" = '2021-12-01 07:42:02.281920' WHERE "mall_shop"."id" = 3; args=('투썸플레이스', 'not used description', '042-123-1234', '', '2021-12-01 06:40:55.474802', '2021-12-01 07:42:02.281920', 3)
# (0.015) UPDATE "mall_shop" SET "name" = '셀프24시빨래방', "description" = 'not used description', "telephone" = '042-1234-4321', "photo" = '', "created_at" = '2021-12-01 06:05:05.894476', "updated_at" = '2021-12-01 07:42:02.296789' WHERE "mall_shop"."id" = 2; args=('셀프24시빨래방', 'not used description', '042-1234-4321', '', '2021-12-01 06:05:05.894476', '2021-12-01 07:42:02.296789', 2)
# (0.016) UPDATE "mall_shop" SET "name" = '투썸플레이스', "description" = 'not used description', "telephone" = '042-123-1234', "photo" = '', "created_at" = '2021-12-01 06:02:40.227975', "updated_at" = '2021-12-01 07:42:02.311571' WHERE "mall_shop"."id" = 1; args=('투썸플레이스', 'not used description', '042-123-1234', '', '2021-12-01 06:02:40.227975', '2021-12-01 07:42:02.311571', 1)

# %% [markdown]
# # Delete Rows

# %%
# qs = Shop.objects.all()

# %%
# qs.delete()
